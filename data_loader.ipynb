# %%
# Importing necessary libraries
from matplotlib import legend
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import os
import numpy as np
from icecream import ic
from tqdm import tqdm
from itertools import chain
from get_data import get_data
import logging
import os
import cProfile
import pstats

# %%
from get_data import get_data

data = get_data(path = "save_data_test.csv")

# %%
dataset = CustomDataset(data[0:1, 150:200, :], 10)
data_loader = DataLoader(dataset, batch_size=5)

# %%
# Split data into train and test sets
train_size = int(0.5 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
data_loader = DataLoader(train_dataset, batch_size=5)

# %%
x,y = next(iter(data_loader))

# %%
data_loader = DataLoader(dataset, batch_size=5)
for j, (x,y) in enumerate(data_loader):
 if j>5:
    plt.plot(x[0,:,1], label=f"j{j}")
    plt.plot(x[1,:,1], label=f"j{j+1}")
    plt.plot(x[2,:,1], label=f"j{j+2}")
    plt.plot(x[3,:,1], label=f"j{j+3}")
plt.legend()
plt.show()
